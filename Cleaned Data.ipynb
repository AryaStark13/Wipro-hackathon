# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing and cleaning the Train set

# %%
train_set = pd.read_csv(r"C:\Users\ariha\Desktop\Hackathons & Projects\Wipro Hackathon\train.csv")
train_set
# Out:
#         Year  Month  Day  Hour  Minute  Clearsky DHI  Clearsky DNI  \
# 0       2009      1    1     0       0             0             0
# 1       2009      1    1     0      30             0             0
# 2       2009      1    1     1       0             0             0
# 3       2009      1    1     1      30             0             0
# 4       2009      1    1     2       0             0             0
# ...      ...    ...  ...   ...     ...           ...           ...
# 175291  2018     12   31    21      30            51           555
# 175292  2018     12   31    22       0            37           388
# 175293  2018     12   31    22      30            15           115
# 175294  2018     12   31    23       0             0             0
# 175295  2018     12   31    23      30             0             0
#
#         Clearsky GHI  Cloud Type  Dew Point  Temperature  Pressure  \
# 0                  0           0        0.0          5.0      1010
# ...

# %%
test_set = pd.read_csv(r"C:\Users\ariha\Desktop\Hackathons & Projects\Wipro Hackathon\test.csv")
test_set
# Out:
#        Year  Month  Day  Hour  Minute  Cloud Type  Dew Point  Temperature  \
# 0      2019      1    1     0       0           7       18.4         18.8
# 1      2019      1    1     0      30           3       18.4         18.6
# 2      2019      1    1     1       0           3       18.2         18.5
# 3      2019      1    1     1      30           3       18.2         18.3
# 4      2019      1    1     2       0           0       18.0         18.0
# ...     ...    ...  ...   ...     ...         ...        ...          ...
# 17515  2019     12   31    21      30           0        5.6         11.1
# 17516  2019     12   31    22       0           0        5.7          9.3
# 17517  2019     12   31    22      30           0        5.7          8.5
# 17518  2019     12   31    23       0           0        4.8          7.8
# 17519  2019     12   31    23      30           0        4.8          7.8
#
#        Pressure  Relative Humidity  Solar Zenith Angle  Precipitable Water  \
# ...

# %%
y_train = pd.DataFrame(train_set[['Clearsky DHI', 'Clearsky DNI', 'Clearsky GHI']])
y_train
# Out:
#         Clearsky DHI  Clearsky DNI  Clearsky GHI
# 0                  0             0             0
# 1                  0             0             0
# 2                  0             0             0
# 3                  0             0             0
# 4                  0             0             0
# ...              ...           ...           ...
# 175291            51           555           168
# 175292            37           388            84
# 175293            15           115            18
# 175294             0             0             0
# 175295             0             0             0
#
# [175296 rows x 3 columns]

# %%
y_test = pd.DataFrame(test_set[['Clearsky DHI', 'Clearsky DNI', 'Clearsky GHI']])
y_test
# Out:
#        Clearsky DHI  Clearsky DNI  Clearsky GHI
# 0               NaN           NaN           NaN
# 1               NaN           NaN           NaN
# 2               NaN           NaN           NaN
# 3               NaN           NaN           NaN
# 4               NaN           NaN           NaN
# ...             ...           ...           ...
# 17515           NaN           NaN           NaN
# 17516           NaN           NaN           NaN
# 17517           NaN           NaN           NaN
# 17518           NaN           NaN           NaN
# 17519           NaN           NaN           NaN
#
# [17520 rows x 3 columns]

# %%
x_train = train_set.drop(columns=['Clearsky DHI', 'Clearsky DNI', 'Clearsky GHI'], axis=1)
x_train
# Out:
#         Year  Month  Day  Hour  Minute  Cloud Type  Dew Point  Temperature  \
# 0       2009      1    1     0       0           0        0.0          5.0
# 1       2009      1    1     0      30           0        1.0          5.0
# 2       2009      1    1     1       0           4        0.0          5.0
# 3       2009      1    1     1      30           4        0.0          4.0
# 4       2009      1    1     2       0           4        0.0          4.0
# ...      ...    ...  ...   ...     ...         ...        ...          ...
# 175291  2018     12   31    21      30           4       19.4         20.8
# 175292  2018     12   31    22       0           4       19.1         20.1
# 175293  2018     12   31    22      30           7       19.1         19.6
# 175294  2018     12   31    23       0           7       18.7         19.2
# 175295  2018     12   31    23      30           7       18.7         19.2
#
# ...

# %%
x_test = test_set.drop(columns=['Clearsky DHI', 'Clearsky DNI', 'Clearsky GHI'], axis=1)
x_test
# Out:
#        Year  Month  Day  Hour  Minute  Cloud Type  Dew Point  Temperature  \
# 0      2019      1    1     0       0           7       18.4         18.8
# 1      2019      1    1     0      30           3       18.4         18.6
# 2      2019      1    1     1       0           3       18.2         18.5
# 3      2019      1    1     1      30           3       18.2         18.3
# 4      2019      1    1     2       0           0       18.0         18.0
# ...     ...    ...  ...   ...     ...         ...        ...          ...
# 17515  2019     12   31    21      30           0        5.6         11.1
# 17516  2019     12   31    22       0           0        5.7          9.3
# 17517  2019     12   31    22      30           0        5.7          8.5
# 17518  2019     12   31    23       0           0        4.8          7.8
# 17519  2019     12   31    23      30           0        4.8          7.8
#
#        Pressure  Relative Humidity  Solar Zenith Angle  Precipitable Water  \
# ...

# %%
x_train['Date']=pd.to_datetime(x_train[['Year', 'Month', 'Day', 'Hour', 'Minute']])
x_train
# Out:
#         Year  Month  Day  Hour  Minute  Cloud Type  Dew Point  Temperature  \
# 0       2009      1    1     0       0           0        0.0          5.0
# 1       2009      1    1     0      30           0        1.0          5.0
# 2       2009      1    1     1       0           4        0.0          5.0
# 3       2009      1    1     1      30           4        0.0          4.0
# 4       2009      1    1     2       0           4        0.0          4.0
# ...      ...    ...  ...   ...     ...         ...        ...          ...
# 175291  2018     12   31    21      30           4       19.4         20.8
# 175292  2018     12   31    22       0           4       19.1         20.1
# 175293  2018     12   31    22      30           7       19.1         19.6
# 175294  2018     12   31    23       0           7       18.7         19.2
# 175295  2018     12   31    23      30           7       18.7         19.2
#
# ...

# %%
x_train.drop(columns=['Year', 'Month', 'Day', 'Hour', 'Minute'], axis=1, inplace=True)
x_train
# Out:
#         Cloud Type  Dew Point  Temperature  Pressure  Relative Humidity  \
# 0                0        0.0          5.0      1010              75.34
# 1                0        1.0          5.0      1010              80.81
# 2                4        0.0          5.0      1010              78.27
# 3                4        0.0          4.0      1010              78.27
# 4                4        0.0          4.0      1010              76.45
# ...            ...        ...          ...       ...                ...
# 175291           4       19.4         20.8      1008              91.77
# 175292           4       19.1         20.1      1008              93.88
# 175293           7       19.1         19.6      1008              96.83
# 175294           7       18.7         19.2      1009              96.84
# 175295           7       18.7         19.2      1009              96.84
#
#         Solar Zenith Angle  Precipitable Water  Wind Direction  Wind Speed  \
# ...

# %%
x_test['Date']=pd.to_datetime(x_test[['Year', 'Month', 'Day', 'Hour', 'Minute']])
x_test.drop(columns=['Year', 'Month', 'Day', 'Hour', 'Minute'], axis=1, inplace=True)
x_test
# Out:
#        Cloud Type  Dew Point  Temperature  Pressure  Relative Humidity  \
# 0               7       18.4         18.8      1008              97.70
# 1               3       18.4         18.6      1008              98.92
# 2               3       18.2         18.5      1008              98.35
# 3               3       18.2         18.3      1008              99.58
# 4               0       18.0         18.0      1008              99.71
# ...           ...        ...          ...       ...                ...
# 17515           0        5.6         11.1      1006              68.64
# 17516           0        5.7          9.3      1006              78.31
# 17517           0        5.7          8.5      1006              82.64
# 17518           0        4.8          7.8      1006              81.49
# 17519           0        4.8          7.8      1006              81.49
#
#        Solar Zenith Angle  Precipitable Water  Wind Direction  Wind Speed  \
# ...

# %%
corr_matrix = x_train.corr()
corr_matrix
# Out:
#                     Cloud Type  Dew Point  Temperature  Pressure  \
# Cloud Type            1.000000   0.202096     0.066777 -0.137158
# Dew Point             0.202096   1.000000     0.848948 -0.419534
# Temperature           0.066777   0.848948     1.000000 -0.371395
# Pressure             -0.137158  -0.419534    -0.371395  1.000000
# Relative Humidity     0.235374   0.193455    -0.341914 -0.085004
# Solar Zenith Angle    0.026873  -0.222336    -0.526548  0.078900
# Precipitable Water    0.326904   0.881881     0.742449 -0.365342
# Wind Direction       -0.081565  -0.076357    -0.066673 -0.182006
# Wind Speed            0.072632  -0.140699    -0.046694 -0.122674
# Fill Flag             0.090161   0.036851     0.015734  0.052521
#
#                     Relative Humidity  Solar Zenith Angle  Precipitable Water  \
# Cloud Type                   0.235374            0.026873            0.326904
# Dew Point                    0.193455           -0.222336            0.881881
# ...

# %%
import numpy as np
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
# C:\Users\ariha\AppData\Local\Temp/ipykernel_2412/2940838402.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#                     Cloud Type  Dew Point  Temperature  Pressure  \
# Cloud Type                 NaN   0.202096     0.066777 -0.137158
# Dew Point                  NaN        NaN     0.848948 -0.419534
# Temperature                NaN        NaN          NaN -0.371395
# Pressure                   NaN        NaN          NaN       NaN
# Relative Humidity          NaN        NaN          NaN       NaN
# Solar Zenith Angle         NaN        NaN          NaN       NaN
# ...

# %%
columns_to_drop = []
for cols in upper.columns:
    if any (upper[cols] > 0.75):
        columns_to_drop.append(cols)
columns_to_drop
# Out:
# ['Temperature', 'Precipitable Water']

# %%
x_train.drop(columns=columns_to_drop, axis=1, inplace=True)
x_train.head()
# Out:
#    Cloud Type  Dew Point  Pressure  Relative Humidity  Solar Zenith Angle  \
# 0           0        0.0      1010              75.34              106.15
# 1           0        1.0      1010              80.81              112.28
# 2           4        0.0      1010              78.27              118.50
# 3           4        0.0      1010              78.27              124.78
# 4           4        0.0      1010              76.45              131.12
#
#    Wind Direction  Wind Speed  Fill Flag                Date
# 0           346.1         3.1          0 2009-01-01 00:00:00
# 1           346.1         3.1          0 2009-01-01 00:30:00
# 2           347.9         3.2          0 2009-01-01 01:00:00
# 3           347.9         3.1          0 2009-01-01 01:30:00
# 4           350.0         3.0          0 2009-01-01 02:00:00

# %%
x_test.drop(columns=columns_to_drop, axis=1, inplace=True)
x_test.head()
# Out:
#    Cloud Type  Dew Point  Pressure  Relative Humidity  Solar Zenith Angle  \
# 0           7       18.4      1008              97.70              106.23
# 1           3       18.4      1008              98.92              112.36
# 2           3       18.2      1008              98.35              118.58
# 3           3       18.2      1008              99.58              124.86
# 4           0       18.0      1008              99.71              131.20
#
#    Wind Direction  Wind Speed  Fill Flag                Date
# 0             190         2.3          0 2019-01-01 00:00:00
# 1             187         2.5          0 2019-01-01 00:30:00
# 2             184         2.8          0 2019-01-01 01:00:00
# 3             185         3.0          0 2019-01-01 01:30:00
# 4             186         3.1          0 2019-01-01 02:00:00

# %%
columns_list = []
for cols in x_train.columns:
    columns_list.append(cols)
    
columns_list
# Out:
# ['Cloud Type',
#  'Dew Point',
#  'Pressure',
#  'Relative Humidity',
#  'Solar Zenith Angle',
#  'Wind Direction',
#  'Wind Speed',
#  'Fill Flag',
#  'Date']

# %%
columns_list.remove('Date')
columns_list.insert(0, 'Date')
columns_list
# Out:
# ['Date',
#  'Cloud Type',
#  'Dew Point',
#  'Pressure',
#  'Relative Humidity',
#  'Solar Zenith Angle',
#  'Wind Direction',
#  'Wind Speed',
#  'Fill Flag']

# %%
x_train = x_train[columns_list]
x_train.head()
# Out:
#                  Date  Cloud Type  Dew Point  Pressure  Relative Humidity  \
# 0 2009-01-01 00:00:00           0        0.0      1010              75.34
# 1 2009-01-01 00:30:00           0        1.0      1010              80.81
# 2 2009-01-01 01:00:00           4        0.0      1010              78.27
# 3 2009-01-01 01:30:00           4        0.0      1010              78.27
# 4 2009-01-01 02:00:00           4        0.0      1010              76.45
#
#    Solar Zenith Angle  Wind Direction  Wind Speed  Fill Flag
# 0              106.15           346.1         3.1          0
# 1              112.28           346.1         3.1          0
# 2              118.50           347.9         3.2          0
# 3              124.78           347.9         3.1          0
# 4              131.12           350.0         3.0          0

# %%
x_test = x_test[columns_list]
x_test.head()
# Out:
#                  Date  Cloud Type  Dew Point  Pressure  Relative Humidity  \
# 0 2019-01-01 00:00:00           7       18.4      1008              97.70
# 1 2019-01-01 00:30:00           3       18.4      1008              98.92
# 2 2019-01-01 01:00:00           3       18.2      1008              98.35
# 3 2019-01-01 01:30:00           3       18.2      1008              99.58
# 4 2019-01-01 02:00:00           0       18.0      1008              99.71
#
#    Solar Zenith Angle  Wind Direction  Wind Speed  Fill Flag
# 0              106.23             190         2.3          0
# 1              112.36             187         2.5          0
# 2              118.58             184         2.8          0
# 3              124.86             185         3.0          0
# 4              131.20             186         3.1          0

# %%
x_train['Fill Flag'].value_counts()
# Out:
# 0      164285
# 4        6864
# 1        2046
# 100       454
# 3         290
# 14        204
# 43        157
# 29        151
# 57        106
# 71         95
# 7          93
# 86         81
# 11         60
# 25         48
# 18         46
# 32         36
# 36         36
# 21         34
# 39         31
# 46         27
# 93         21
# 50         17
# 75         17
# 64         16
# 96         16
# 89         14
# 68         12
# 61         11
# 54         11
# 79          9
# 82          8
# Name: Fill Flag, dtype: int64

# %%
x_train['Cloud Type'].value_counts()
# Out:
# 0     82788
# 7     23163
# 3     16255
# 1     15698
# 8     14276
# 4     11738
# 6      7902
# 2      3018
# 9       457
# 10        1
# Name: Cloud Type, dtype: int64

# %%
for cols in x_train:
    if cols != 'Date':
        x_train[cols] = (x_train[cols] - x_train[cols].mean()) / x_train[cols].std()
x_train
# Out:
#                       Date  Cloud Type  Dew Point  Pressure  \
# 0      2009-01-01 00:00:00   -0.840694  -1.654847  1.148089
# 1      2009-01-01 00:30:00   -0.840694  -1.532848  1.148089
# 2      2009-01-01 01:00:00    0.482986  -1.654847  1.148089
# 3      2009-01-01 01:30:00    0.482986  -1.654847  1.148089
# 4      2009-01-01 02:00:00    0.482986  -1.654847  1.148089
# ...                    ...         ...        ...       ...
# 175291 2018-12-31 21:30:00    0.482986   0.711934  0.811148
# 175292 2018-12-31 22:00:00    0.482986   0.675334  0.811148
# 175293 2018-12-31 22:30:00    1.475746   0.675334  0.811148
# 175294 2018-12-31 23:00:00    1.475746   0.626534  0.979619
# 175295 2018-12-31 23:30:00    1.475746   0.626534  0.979619
#
#         Relative Humidity  Solar Zenith Angle  Wind Direction  Wind Speed  \
# 0               -0.205118            0.409638        1.587867    0.653036
# 1                0.072854            0.562562        1.587867    0.653036
# ...

# %%
for cols in x_test:
    if cols != 'Date':
        x_test[cols] = (x_test[cols] - x_test[cols].mean()) / x_test[cols].std()
x_test
# Out:
#                      Date  Cloud Type  Dew Point  Pressure  Relative Humidity  \
# 0     2019-01-01 00:00:00    1.355763   0.519194  0.263273           1.119914
# 1     2019-01-01 00:30:00    0.089934   0.519194  0.263273           1.180544
# 2     2019-01-01 01:00:00    0.089934   0.491698  0.263273           1.152217
# 3     2019-01-01 01:30:00    0.089934   0.491698  0.263273           1.213344
# 4     2019-01-01 02:00:00   -0.859438   0.464201  0.263273           1.219805
# ...                   ...         ...        ...       ...                ...
# 17515 2019-12-31 21:30:00   -0.859438  -1.240576 -0.158426          -0.324277
# 17516 2019-12-31 22:00:00   -0.859438  -1.226828 -0.158426           0.156292
# 17517 2019-12-31 22:30:00   -0.859438  -1.226828 -0.158426           0.371479
# 17518 2019-12-31 23:00:00   -0.859438  -1.350562 -0.158426           0.314328
# 17519 2019-12-31 23:30:00   -0.859438  -1.350562 -0.158426           0.314328
#
# ...

# %%
for cols in y_train:
    y_train[cols] = (y_train[cols] - y_train[cols].mean()) / y_train[cols].std()
y_train
# Out:
#         Clearsky DHI  Clearsky DNI  Clearsky GHI
# 0          -0.826546     -0.891994     -0.776203
# 1          -0.826546     -0.891994     -0.776203
# 2          -0.826546     -0.891994     -0.776203
# 3          -0.826546     -0.891994     -0.776203
# 4          -0.826546     -0.891994     -0.776203
# ...              ...           ...           ...
# 175291     -0.032171      0.607881     -0.263546
# 175292     -0.250235      0.156567     -0.519875
# 175293     -0.592906     -0.581209     -0.721275
# 175294     -0.826546     -0.891994     -0.776203
# 175295     -0.826546     -0.891994     -0.776203
#
# [175296 rows x 3 columns]

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (175296, 9)
# (175296, 3)
# (17520, 9)
# (17520, 3)

# %%
x_train_with_date = x_train
x_train_with_date.head()
# Out:
#                  Date  Cloud Type  Dew Point  Pressure  Relative Humidity  \
# 0 2009-01-01 00:00:00   -0.840694  -1.654847  1.148089          -0.205118
# 1 2009-01-01 00:30:00   -0.840694  -1.532848  1.148089           0.072854
# 2 2009-01-01 01:00:00    0.482986  -1.654847  1.148089          -0.056223
# 3 2009-01-01 01:30:00    0.482986  -1.654847  1.148089          -0.056223
# 4 2009-01-01 02:00:00    0.482986  -1.654847  1.148089          -0.148711
#
#    Solar Zenith Angle  Wind Direction  Wind Speed  Fill Flag
# 0            0.409638        1.587867    0.653036  -0.112602
# 1            0.562562        1.587867    0.653036  -0.112602
# 2            0.717730        1.606046    0.731045  -0.112602
# 3            0.874395        1.606046    0.653036  -0.112602
# 4            1.032558        1.627255    0.575027  -0.112602

# %%
x_train = x_train.drop(columns=['Date'], axis=1)
x_train
# Out:
#         Cloud Type  Dew Point  Pressure  Relative Humidity  \
# 0        -0.840694  -1.654847  1.148089          -0.205118
# 1        -0.840694  -1.532848  1.148089           0.072854
# 2         0.482986  -1.654847  1.148089          -0.056223
# 3         0.482986  -1.654847  1.148089          -0.056223
# 4         0.482986  -1.654847  1.148089          -0.148711
# ...            ...        ...       ...                ...
# 175291    0.482986   0.711934  0.811148           0.629814
# 175292    0.482986   0.675334  0.811148           0.737039
# 175293    1.475746   0.675334  0.811148           0.886951
# 175294    1.475746   0.626534  0.979619           0.887459
# 175295    1.475746   0.626534  0.979619           0.887459
#
#         Solar Zenith Angle  Wind Direction  Wind Speed  Fill Flag
# 0                 0.409638        1.587867    0.653036  -0.112602
# 1                 0.562562        1.587867    0.653036  -0.112602
# ...

# %%
x_test_with_date = x_test
x_test_with_date.head()
# Out:
#                  Date  Cloud Type  Dew Point  Pressure  Relative Humidity  \
# 0 2019-01-01 00:00:00    1.355763   0.519194  0.263273           1.119914
# 1 2019-01-01 00:30:00    0.089934   0.519194  0.263273           1.180544
# 2 2019-01-01 01:00:00    0.089934   0.491698  0.263273           1.152217
# 3 2019-01-01 01:30:00    0.089934   0.491698  0.263273           1.213344
# 4 2019-01-01 02:00:00   -0.859438   0.464201  0.263273           1.219805
#
#    Solar Zenith Angle  Wind Direction  Wind Speed  Fill Flag
# 0            0.412296        0.056613    0.038039    -0.2737
# 1            0.565205        0.025898    0.199465    -0.2737
# 2            0.720358       -0.004817    0.441605    -0.2737
# 3            0.877008        0.005421    0.603031    -0.2737
# 4            1.035154        0.015660    0.683744    -0.2737

# %%
x_test = x_test.drop(columns=['Date'], axis=1)
x_test
# Out:
#        Cloud Type  Dew Point  Pressure  Relative Humidity  Solar Zenith Angle  \
# 0        1.355763   0.519194  0.263273           1.119914            0.412296
# 1        0.089934   0.519194  0.263273           1.180544            0.565205
# 2        0.089934   0.491698  0.263273           1.152217            0.720358
# 3        0.089934   0.491698  0.263273           1.213344            0.877008
# 4       -0.859438   0.464201  0.263273           1.219805            1.035154
# ...           ...        ...       ...                ...                 ...
# 17515   -0.859438  -1.240576 -0.158426          -0.324277           -0.294623
# 17516   -0.859438  -1.226828 -0.158426           0.156292           -0.165662
# 17517   -0.859438  -1.226828 -0.158426           0.371479           -0.033956
# 17518   -0.859438  -1.350562 -0.158426           0.314328            0.116458
# 17519   -0.859438  -1.350562 -0.158426           0.314328            0.263130
#
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(x_train_with_date['Date'][0:144], y_train['Clearsky DHI'][0:144])

# %%
plt.figure(figsize=(12, 6))
plt.plot(x_train_with_date['Date'][0:35040], y_train['Clearsky DHI'][0:35040])

# %% [markdown]
# * Test excel sheet: Unknown Clearsky values, to be used for final testing <br>
# * Train excel sheet: All known values, to be used for training and validation <br>
#
# * x_train, y_train, x_val, y_val will all be from the same *test* excel sheet <br>
# * x_test, y_test(AKA y_pred) will be from *test* excel sheet
# <br>
# Maybe, dont use x_val, y_val and train only on x_train_without_date, y_train and predict based on x_test and y_test. Upload the final csv to the machine hack website to get the MSE score

# %%
len(y_train)
# Out:
# 175296

# %%
x_val = pd.DataFrame(x_train[int(len(x_train) * 0.90):])
y_val = pd.DataFrame(y_train[int(len(y_train) * 0.90):])

# %%
x_val
# Out:
#         Cloud Type  Dew Point  Pressure  Relative Humidity  \
# 157766    0.482986  -1.532848  1.148089          -0.671115
# 157767   -0.509774  -1.532848  1.148089          -0.431256
# 157768   -0.509774  -1.532848  1.148089          -0.303196
# 157769   -0.178854  -1.532848  1.148089          -0.034371
# 157770   -0.840694  -1.532848  1.148089           0.067264
# ...            ...        ...       ...                ...
# 175291    0.482986   0.711934  0.811148           0.629814
# 175292    0.482986   0.675334  0.811148           0.737039
# 175293    1.475746   0.675334  0.811148           0.886951
# 175294    1.475746   0.626534  0.979619           0.887459
# 175295    1.475746   0.626534  0.979619           0.887459
#
#         Solar Zenith Angle  Wind Direction  Wind Speed  Fill Flag
# 157766           -0.785808        1.436374   -0.205063  -0.112602
# 157767           -0.716705        1.436374   -0.127054  -0.112602
# ...
